# %%
"""
target: one layer classification
dataset: fashion mnist, a 10 classes dataset
"""
# Out:
# '\ntarget: one layer classification\ndataset: fashion mnist, a 10 classes dataset\n'

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## load fashion mnist data

# %%
# %run read_fashion_image.ipynb

# %%
x_train, y_train, x_test, y_test = get_data()

# %% [markdown]
# ## 归一化

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# ## 维度变换

# %%
x_train = np.array([x.reshape(28,28) for x in x_train ])
x_test = np.array([x.reshape(28,28) for x in x_test ])

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# ## 画出前10个图片

# %%
def get_fashion_mnist_labels(labels):
    text_labels = ['t-shirt', 'trouser', 'pullover', 'dress', 'coat',
                   'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']
    return [text_labels[int(i)] for i in labels]

def show_fashion_mnist(images, labels):
    _, figs = plt.subplots(1, len(images), figsize=(12, 12))
    for f, img, lbl in zip(figs, images, labels):
        f.imshow(img.reshape((28, 28)))
        f.set_title(lbl)
        f.axes.get_xaxis().set_visible(False)
        f.axes.get_yaxis().set_visible(False)
    plt.show()
    
X, y = [], []
for i in range(10):
    X.append(x_train[i])
    y.append(y_train[i])
show_fashion_mnist(X, get_fashion_mnist_labels(y))

# %% [markdown]
# ## 定义单层全连接网络

# %%
model = tf.keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %% [markdown]
# ## 初始化模型参数

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(0.1),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 训练模型

# %%
model.fit(x_train, y_train, epochs=5, batch_size=256)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 1s 17us/sample - loss: 0.7915 - accuracy: 0.7455
# Epoch 2/5
# 60000/60000 [==============================] - 1s 8us/sample - loss: 0.5733 - accuracy: 0.8098
# Epoch 3/5
# 60000/60000 [==============================] - 0s 8us/sample - loss: 0.5282 - accuracy: 0.8239
# Epoch 4/5
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.5037 - accuracy: 0.8307
# Epoch 5/5
# 60000/60000 [==============================] - 1s 9us/sample - loss: 0.4883 - accuracy: 0.8355

# %% [markdown]
# ## 在测试集上验证效果

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
print('Test Acc:',test_acc)
# Out:
# Test Acc: 0.8265

# %%
"""
问题

为什么要归一化数据？ 归一化是为了防止求解出的梯度过大，比如 多层神经网络可能出现255*255*255的梯度

Flattern层是把多维数据压平为一维数据
Dense层是全连接层

为什么是直接设置activation，而不是单独设置一个softmax层？
还有哪些activation？ 难道不是tanh relu leakyrelu 那些吗？

只有输出层才需要设置activation吗？

batch大小如何设置

batch和mini batch的区别？ 
网上看到一种说法，mini batch是用在sgd阶段的，常规的sgd每次只随机挑选一个样本计算梯度，mini batch每次挑选n个

sgd的概念，sgd的参数0.1是什么含义？学习率。

sparse crossentropy 与 crossentropy的区别
如果你的 targets 是 one-hot 编码，用 categorical_crossentropy
　　one-hot 编码：[0, 0, 1], [1, 0, 0], [0, 1, 0]
如果你的 tagets 是 数字编码 ，用 sparse_categorical_crossentropy
　　数字编码：2, 0, 1
  
accuracy是如何计算的？对于每个样本，取预测概率最大值对应的类别作为输出类别，计算每个样本预测是否正确，用预测正确的数量除以总样本量。

"""
